# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Load Data

# %%
#파일 불러오기
train_data = './data/train.csv'
test_data ='./data/test.csv'
submission = './data/sample_submission.csv'

train = pd.read_csv(train_data, index_col='ID_code')
test = pd.read_csv(test_data, index_col='ID_code')
submission = pd.read_csv(submission, index_col='ID_code')

# %% [markdown]
# ### 1. Data 확인 하기

# %%
print(train.shape)
train.head()
# Out:
# (200000, 201)
#          target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# ID_code
# train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#            var_7   var_8   ...     var_190  var_191  var_192  var_193  \
# ID_code                    ...
# train_0  18.6266 -4.9200   ...      4.4354   3.9642   3.1364   1.6910
# train_1  16.5338  3.1468   ...      7.6421   7.7214   2.5837  10.9516
# train_2  14.6155 -4.9193   ...      2.9057   9.7905   1.6704   1.6858
# train_3  14.9250 -5.8609   ...      4.4666   4.7433   0.7178   1.4214
# train_4  19.2514  6.2654   ...     -1.4905   9.5214  -0.1508   9.1942
#
# ...

# %%
print(test.shape)
test.head()
# Out:
# (200000, 200)
#            var_0    var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# ID_code
# test_0   11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493  18.2675
# test_1    8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196  18.6316
# test_2    5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950  20.2537
# test_3    8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397  20.5660
# test_4   11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595  10.6048
#
#           var_8   var_9   ...     var_190  var_191  var_192  var_193  var_194  \
# ID_code                   ...
# test_0   2.1337  8.8100   ...     -2.1556  11.8495  -1.4300   2.4508  13.7112
# test_1  -4.4131  5.9739   ...     10.6165   8.8349   0.9403  10.1282  15.5765
# test_2   1.5233  8.3442   ...     -0.7484  10.9935   1.9803   2.1800  12.9813
# test_3   3.3755  7.4578   ...      9.5702   9.0766   1.6580   3.5813  15.1874
# ...

# %%
print(submission.shape)
submission.head()
# Out:
# (200000, 1)
#          target
# ID_code
# test_0        0
# test_1        0
# test_2        0
# test_3        0
# test_4        0

# %%
train.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
test.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# ...

# %%
#data type 확인 하기
print(train.dtypes.unique())
print(test.dtypes.unique())
train.dtypes
# Out:
# [dtype('int64') dtype('float64')]
# [dtype('float64')]
# target       int64
# var_0      float64
# var_1      float64
# var_2      float64
# var_3      float64
# var_4      float64
# var_5      float64
# var_6      float64
# var_7      float64
# var_8      float64
# var_9      float64
# var_10     float64
# var_11     float64
# var_12     float64
# var_13     float64
# var_14     float64
# var_15     float64
# var_16     float64
# var_17     float64
# var_18     float64
# var_19     float64
# var_20     float64
# var_21     float64
# var_22     float64
# var_23     float64
# var_24     float64
# var_25     float64
# var_26     float64
# var_27     float64
# var_28     float64
#             ...
# var_170    float64
# var_171    float64
# var_172    float64
# var_173    float64
# var_174    float64
# var_175    float64
# var_176    float64
# var_177    float64
# var_178    float64
# var_179    float64
# var_180    float64
# var_181    float64
# var_182    float64
# var_183    float64
# ...

# %%
#null 값 확인 하기
num_null = train.isnull().sum()
num_null = list(num_null)
num_null = [i for i in num_null if i == True]
len(num_null)
# Out:
# 0

# %%
#label distribution 확인 하기
train['target'].value_counts()
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
print(train['target'].value_counts())
ax = sns.countplot(data=train, x='target')
ax
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
a = (179902/(179902+20098)) * 100
b = (20098/(179902+20098)) * 100
print("0의 비중: %.2f" %a)
print("1의 비중: %.2f" %b)
# Out:
# 0의 비중: 89.95
# 1의 비중: 10.05

# %% [markdown]
# #### Summary
#     1. Label distribution이 '0' 값의 데이터의 비중이 89.95%으로 트레이닝 데이터 활용시 Balancing이 필요함.
#     2. 각 feature가 모두 float dtypes이라 별도의 dtype 변경은 필요 없으나, normalizing은 필요함.
