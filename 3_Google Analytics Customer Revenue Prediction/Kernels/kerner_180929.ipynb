# %% [markdown]
# # Google Analytics Customer Revenue Prediction

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pandas.io.json import json_normalize
# %matplotlib inline

# %% [markdown]
# ## 2. Data Loading

# %%
def load_df(csv_path='../data/train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path,
                     parse_dates=['date'],
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    return df

# %%
# %%time
train = load_df()
test = load_df('../data/test.csv')
# Out:
# CPU times: user 3min 55s, sys: 12.3 s, total: 4min 7s
# Wall time: 4min 5s

# %% [markdown]
# ## 3. Feature Exploration

# %% [markdown]
# ### Data Fields
# * fullVisitorId- A unique identifier for each user of the Google Merchandise Store.
# * channelGrouping - The channel via which the user came to the Store.
# * date - The date on which the user visited the Store.
# * device - The specifications for the device used to access the Store.
# * geoNetwork - This section contains information about the geography of the user.
# * sessionId - A unique identifier for this visit to the store.
# * socialEngagementType - Engagement type, either "Socially Engaged" or "Not Socially Engaged".
# * totals - This section contains aggregate values across the session.
# * trafficSource - This section contains information about the Traffic Source from which the session originated.
# * visitId - An identifier for this session. This is part of the value usually stored as the _utmb cookie. This is only unique to the user. For a completely unique ID, you *  should use a combination of fullVisitorId and visitId.
# * visitNumber - The session number for this user. If this is the first session, then this is set to 1.
# * visitStartTime - The timestamp (expressed as POSIX time).

# %%
train.head()
# Out:
#   channelGrouping       date        fullVisitorId  \
# 0  Organic Search 2016-09-02  1131660440785968503
# 1  Organic Search 2016-09-02   377306020877927890
# 2  Organic Search 2016-09-02  3895546263509774583
# 3  Organic Search 2016-09-02  4763447161404445595
# 4  Organic Search 2016-09-02    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime device.browser             device.browserSize  \
# 0            1      1472830385         Chrome  not available in demo dataset
# 1            1      1472880147        Firefox  not available in demo dataset
# 2            1      1472865386         Chrome  not available in demo dataset
# 3            1      1472881213     UC Browser  not available in demo dataset
# 4            2      1472822600         Chrome  not available in demo dataset
#
#           ...          trafficSource.adwordsClickInfo.isVideoAd  \
# 0         ...                                               NaN
# 1         ...                                               NaN
# 2         ...                                               NaN
# 3         ...                                               NaN
# 4         ...                                               NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    trafficSource.campaign trafficSource.campaignCode  \
# 0               (not set)                        NaN
# 1               (not set)                        NaN
# 2               (not set)                        NaN
# 3               (not set)                        NaN
# 4               (not set)                        NaN
#
#   trafficSource.isTrueDirect trafficSource.keyword trafficSource.medium  \
# 0                        NaN        (not provided)              organic
# 1                        NaN        (not provided)              organic
# 2                        NaN        (not provided)              organic
# 3                        NaN       google + online              organic
# 4                       True        (not provided)              organic
#
#   trafficSource.referralPath trafficSource.source
# 0                        NaN               google
# 1                        NaN               google
# 2                        NaN               google
# 3                        NaN               google
# 4                        NaN               google
#
# [5 rows x 55 columns]

# %%
test.head()
# Out:
#   channelGrouping       date        fullVisitorId  \
# 0  Organic Search 2017-10-16  6167871330617112363
# 1  Organic Search 2017-10-16  0643697640977915618
# 2  Organic Search 2017-10-16  6059383810968229466
# 3  Organic Search 2017-10-16  2376720078563423631
# 4  Organic Search 2017-10-16  2314544520795440038
#
#                         sessionId  socialEngagementType     visitId  \
# 0  6167871330617112363_1508151024  Not Socially Engaged  1508151024
# 1  0643697640977915618_1508175522  Not Socially Engaged  1508175522
# 2  6059383810968229466_1508143220  Not Socially Engaged  1508143220
# 3  2376720078563423631_1508193530  Not Socially Engaged  1508193530
# 4  2314544520795440038_1508217442  Not Socially Engaged  1508217442
#
#    visitNumber  visitStartTime device.browser             device.browserSize  \
# 0            2      1508151024         Chrome  not available in demo dataset
# 1            1      1508175522         Chrome  not available in demo dataset
# 2            1      1508143220         Chrome  not available in demo dataset
# 3            1      1508193530         Safari  not available in demo dataset
# 4            1      1508217442         Safari  not available in demo dataset
#
#           ...          trafficSource.adwordsClickInfo.gclId  \
# 0         ...                                           NaN
# 1         ...                                           NaN
# 2         ...                                           NaN
# 3         ...                                           NaN
# 4         ...                                           NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page  trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0              (not set)                       True        (not provided)
# 1              (not set)                        NaN        (not provided)
# 2              (not set)                        NaN        (not provided)
# 3              (not set)                        NaN        (not provided)
# 4              (not set)                        NaN        (not provided)
#
#   trafficSource.medium trafficSource.referralPath trafficSource.source
# 0              organic                        NaN               google
# 1              organic                        NaN               google
# 2              organic                        NaN               google
# 3              organic                        NaN               google
# 4              organic                        NaN               google
#
# [5 rows x 53 columns]

# %% [markdown]
# ### 3-1 Missing Column
# * what is a missing column of test data?

# %%
train_col = train.columns
test_col = test.columns

# %%
train_col.isin(test_col)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True])

# %%
train_col[-16], train_col[-6],
# Out:
# ('totals.transactionRevenue', 'trafficSource.campaignCode')

# %%
#drop the missing column of train data
train=train.drop('trafficSource.campaignCode', axis=1)

# %%
train.shape, test.shape
# Out:
# ((903653, 54), (804684, 53))

# %% [markdown]
# ### 3-2 Feature Engineering
# * drop useless features
# * classifing dtypes of features

# %%
Number=['visitNumber','totals.bounces','totals.hits','totals.newVisits','totals.pageviews','totals.transactionRevenue']
useless=['sessionId','socialEngagementType','device.browser','device.browserSize','device.browserVersion','device.flashVersion','device.language',
         'device.mobileDeviceBranding', 'device.mobileDeviceInfo','device.mobileDeviceMarketingName','device.mobileDeviceModel','device.mobileInputSelector',
         'device.operatingSystemVersion','device.screenColors','device.screenResolution','geoNetwork.cityId','geoNetwork.latitude','geoNetwork.longitude',
         'geoNetwork.networkDomain','geoNetwork.networkLocation','trafficSource.adContent','trafficSource.adwordsClickInfo.criteriaParameters',
         'trafficSource.adwordsClickInfo.gclId','trafficSource.adwordsClickInfo.isVideoAd','trafficSource.adwordsClickInfo.page','trafficSource.adwordsClickInfo.slot',
         'trafficSource.referralPath','trafficSource.source']        
ID=['fullVisitorId']
date=['date']
timestamp=['visitStartTime']
ambiguous=['sessionId','visitId','device.operatingSystem','totals.visits']
blooen=['device.isMobile']

# %%
train.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'device.browser', 'device.browserSize', 'device.browserVersion',
#        'device.deviceCategory', 'device.flashVersion', 'device.isMobile',
#        'device.language', 'device.mobileDeviceBranding',
#        'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName',
#        'device.mobileDeviceModel', 'device.mobileInputSelector',
#        'device.operatingSystem', 'device.operatingSystemVersion',
#        'device.screenColors', 'device.screenResolution', 'geoNetwork.city',
#        'geoNetwork.cityId', 'geoNetwork.continent', 'geoNetwork.country',
#        'geoNetwork.latitude', 'geoNetwork.longitude', 'geoNetwork.metro',
#        'geoNetwork.networkDomain', 'geoNetwork.networkLocation',
#        'geoNetwork.region', 'geoNetwork.subContinent', 'totals.bounces',
#        'totals.hits', 'totals.newVisits', 'totals.pageviews',
#        'totals.transactionRevenue', 'totals.visits', 'trafficSource.adContent',
#        'trafficSource.adwordsClickInfo.adNetworkType',
#        'trafficSource.adwordsClickInfo.criteriaParameters',
#        'trafficSource.adwordsClickInfo.gclId',
#        'trafficSource.adwordsClickInfo.isVideoAd',
#        'trafficSource.adwordsClickInfo.page',
#        'trafficSource.adwordsClickInfo.slot', 'trafficSource.campaign',
#        'trafficSource.isTrueDirect', 'trafficSource.keyword',
#        'trafficSource.medium', 'trafficSource.referralPath',
#        'trafficSource.source'],
#       dtype='object')

# %%
print(train['trafficSource.source'].unique())
print(train['trafficSource.source'].nunique())
train['trafficSource.source'].isnull().sum()/train.shape[0]
# Out:
# ['google' 'baidu' 'googleweblight.com' 'sites.google.com' 'bing'
#  'siliconvalley.about.com' 'analytics.google.com' 'Partners' '(direct)'
#  'mall.googleplex.com' 'google.com' 'google.co.in' 'qiita.com' 'google.pl'
#  'mail.google.com' 'hangouts.google.com' 'dealspotr.com'
#  'optimize.google.com' 'arstechnica.com' 'dfa' 'docs.google.com'
#  'sashihara.jp' 'google.gatewaycdi.com' 'phandroid.com' 'images.google'
#  'youtube.com' 'l.facebook.com' 'facebook.com' 'quora.com'
#  'm.facebook.com' 'reddit.com' 'google.co.jp' 'aol' 'moma.corp.google.com'
#  'blog.golang.org' 'yahoo' 't.co' 'nordic.businessinsider.com'
#  'duckduckgo.com' 'm.baidu.com' 'tpc.googlesyndication.com'
#  'googleads.g.doubleclick.net'
#  '0.shared.bow.cat2.ads-bow.vu.borg.google.com:9856' 'online-metrics.com'
#  'cv.il3.ub.edu' 'gophergala.com' 'plus.google.com' 's0.2mdn.net'
#  'keep.google.com' 'svirkar.mtv.corp.google.com:8888'
#  'connect.googleforwork.com' 'google.com.pk' 'support.google.com'
#  'gdeals.googleplex.com' 'google.com.au' 'int.search.tb.ask.com'
#  'googleux.perksplus.com' 'groups.google.com' 'm.youtube.com'
#  'productforums.google.com' 'web.skype.com' 'ask' 'search.mysearch.com'
#  'course.fso.fullsail.edu' 'google.co.uk'
#  'toronto.mtv.corp.google.com:8080' 'awics.corp.google.com'
#  'aulagrado.esic.edu' 'businessinsider.com' 'outlook.live.com'
#  'lunametrics.com' 'search.tb.ask.com' 'm.reddit.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9801' 'new.vk.com'
#  'linkedin.com' 'm.vk.com' 'google.com.sg' 'lnkd.in'
#  'col128.mail.live.com' 'gsuite.google.com' 'google.ru'
#  'staging.talkgadget.google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9875'
#  'analytics.corp.google.com' 'us.search.yahoo.com' 'search.xfinity.com'
#  'plus.url.google.com' 'google.com.ua' 'csfirst.withgoogle.com' 'yandex'
#  'm.sogou.com' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9850'
#  'images.google.de' 'google.ro' 'pinterest.com' 'google.com.br'
#  'it.search.yahoo.com' 'google.ca' 'google.es'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9815' 'google.co.th'
#  'mail.aol.com' 'cases.corp.google.com' 'cc.csusm.edu'
#  'grow.googleplex.com' 'feedly.com' 'uk.search.yahoo.com'
#  'lm.facebook.com' 'web.facebook.com' 'sg.search.yahoo.com'
#  'search.incredibar.com' 'malaysia.search.yahoo.com' 'github.com'
#  'google.fr' 'suche.t-online.de' 'adwords.google.com'
#  'dynamite.sandbox.google.com' 'g3doc.corp.google.com'
#  'ca.search.yahoo.com' 'drawnames.com' 'search.earthlink.net' 'amazon.com'
#  'tw.search.yahoo.com' 'l.messenger.com' 'inbox.google.com'
#  'au.search.yahoo.com' 'se.search.yahoo.com' 'google.cl' '(not set)'
#  'mg.mail.yahoo.com' 'msn.com' 'apis.mail.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9857' 'google.com.vn'
#  'ph.search.yahoo.com' 'google.com.tw' 'away.vk.com'
#  'datastudio.google.com' 'learn.temple.edu' 'plus.sandbox.google.com'
#  'messenger.com' 'wap.sogou.com' 'kristiyan.users.x20web.corp.google.com'
#  'google.ch' 'trainup.withgoogle.com' 'getpocket.com' 'startpage.com'
#  'google.com.co' 'google.co.kr' 'mail-attachment.googleusercontent.com'
#  'nl.yhs4.search.yahoo.com' 'luyaochen.mtv.corp.google.com:8080'
#  'myactivity.google.com' 'google.it' 'newclasses.nyu.edu' 'google.com.hk'
#  'blognone.com' '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9898'
#  'seroundtable.com' 'gatewaycdi.com' 'vk.com' 'in.search.yahoo.com'
#  'ics-devel-west.qa.adz.google.com' 'google.de' 'google.com.ph'
#  'm.mg.mail.yahoo.com' 'squishable.com' 'twitter.com' 'images.google.ie'
#  'marketingland.com' 'kik.com' 'uweoconnect.extn.washington.edu'
#  'adwords-displayads.googleusercontent.com' 'mysearch.com' 'flipboard.com'
#  'uk.businessinsider.com' 'baidu.com' 'images.google.co.id'
#  'de.pinterest.com' 'se.yhs4.search.yahoo.com'
#  'gtm-preprod-dogfood.corp.google.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9848'
#  'watchword.googleplex.com' 'cn.bing.com' 'google.nl' 'web.telegram.org'
#  'images.google.lk' 'notifications.sandbox.google.com' 'h.yandex-team.ru'
#  'plusapp.sandbox.google.com' 'nl.search.yahoo.com' 'm.yz.sm.cn'
#  'cl-cards.googleplex.com' 'chatwork.com' 'wheretoget.it'
#  'images.google.fr' 'google.com.mx' 'localhost' 'google.cz'
#  'admin.globalaccess.com' 'online.fullsail.edu' 'tumblr.com'
#  'desktop.google.com.ua' 'fr.search.yahoo.com' 'business.facebook.com'
#  'getiriver.com' 'xbidprodmirror.corp.google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9820' 'google.co.id'
#  'allo.corp.google.com' 'amp.reddit.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9885' 'en.wikipedia.org'
#  'kr.pinterest.com' 'finance.yahoo.com'
#  'adwords-next-nightly.qa.adz.google.com' 'markets.businessinsider.com'
#  'google.co.nz' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9835'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9856'
#  'adwords-next-devel.qa.adz.google.com' 'us-mg5.mail.yahoo.com'
#  'kidrex.org' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9861'
#  'earth.google.com' 'goto.google.com' 'so.com' 'cse.google.com'
#  'crowdcompute.googleplex.com' 'spaces.google.com'
#  '0.shared.bow.cat2.ads-bow.vu.borg.google.com:9859' 'mobile.facebook.com'
#  'google.bg' 'news.ycombinator.com' 'search.1and1.com'
#  'learn.colorado.edu' 'search.snapdo.com' 'msn' 'start.wow.com'
#  'us.yhs4.search.yahoo.com' 'bing.com' 'ex.fit.edu' 'searchlock.com'
#  'google.sk' 'fr.yhs4.search.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9896' 'centrum.cz'
#  'ddimitrop.irv.corp.google.com:9001'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9892' 'calendar.google.com'
#  'search.myway.com' 'google.gr' 'ausdroid.net' 'gdeals-stg.googleplex.com'
#  'google.be' 'es.search.yahoo.com' 'int.search.mywebsearch.com'
#  'x20web.corp.google.com' 'dailydot.com' 'redbull.corp.google.com'
#  'oct-obscura.sandbox.google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9849' 'google.co.za'
#  'images.google.co.in' '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819'
#  'plusapp-autopush.corp.google.com' 'login.corp.google.com'
#  'maktoob.search.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9880'
#  'invincible.mtv.corp.google.com:8080' 'go.mail.ru'
#  '0.muppet1.frontend.gws.muppet-exp.ij-q.borg.google.com:14634'
#  'basecamp.com' '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9831'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9885'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9816'
#  'benkraft.mtv.corp.google.com:9000'
#  '0.shared.bow.cat2.ads-bow.tg.borg.google.com:9864' 'chat.google.com'
#  'myaccount.google.com'
#  '0.shared.bow.cat2.ads-bow.vu.borg.google.com:9883' 'google.se'
#  'blackboard.neu.edu' 'fletch.teams.x20web.corp.google.com' 'evernote.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9862' 'ixquick.com'
#  'search.pch.com' 'mail.verizon.com' 'google.co.il' 'wanelo.com'
#  'images.google.at' '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9879'
#  'adwords-displayads-nightly.corp.google.com'
#  '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9817' 'google.com.sa'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9859' 'br.pinterest.com'
#  'pinpoint.corp.google.com' 'prod.facebook.com'
#  '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9824' 'lmgtfy.com'
#  'collaborate.northwestern.edu' 'members.s7.exacttarget.com'
#  'wunderbin.corp.google.com' 'google.at' 'images.google.lt'
#  'web.mail.comcast.net'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9836' 'google.com.ng'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9839' 'ad.doubleclick.net'
#  'oscar.corp.google.com' 'growcms.googleplex.com' 'web.whatsapp.com'
#  'dena-design.qiita.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9895'
#  'papyrus.mtv.corp.google.com:9021' 'yt-go-12345.googleplex.com'
#  'google.rs' '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9899'
#  'ps-dm.reddit.com' 'blackboard.towson.edu' 'risk360-prod.corp.google.com'
#  'images.google.com.au' 'us.reddit.com' 'google.no'
#  '0.shared.bow.cat2.ads-bow.vk.borg.google.com:9878'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9830'
#  'adwords-prod-west.qa.adz.google.com' 'brewmaster.corp.google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9801' 'computerworld.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9865'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9851'
#  '0.shared.bow.cat2.ads-bow.vw.borg.google.com:9891' 'digg.com'
#  'it-mg42.mail.yahoo.com' 'intranet' '9to5google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9813'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9846' 'images.google.pt'
#  'google.lk' 'businessinsider.in' 'newsstand.google.com' 'yahoo.com'
#  'moodle.aurora.edu' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9858'
#  'gtm-dogfood.corp.google.com' 'tweetdeck.twitter.com'
#  'br.search.yahoo.com' 'hosted.verticalresponse.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9859'
#  'cases2.corp.google.com' 'mx.search.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9847'
#  'biztools.corp.google.com' 'us.wow.com' 'm.sp.sm.cn'
#  'hk.search.yahoo.com' 'voice.google.com' 's7-eu4.ixquick.com'
#  'espanol.search.yahoo.com' 'meetup.com'
#  '0.shared.bow.cat2.ads-bow.tl.borg.google.com:9847' 'google.com.ar'
#  'id.search.yahoo.com' 'it.pinterest.com'
#  'mmisciagna2.sbo.corp.google.com:8000' 'google.com.pe'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9834' 'good.barkpost.com'
#  'gist.github.com' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9876'
#  'takeout.google.com' '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9873'
#  '0.shared.bow.cat2.ads-bow.lf.borg.google.com:9860'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898']
# 380
# 0.0

# %%
print(test['trafficSource.source'].unique())
print(test['trafficSource.source'].nunique())
test['trafficSource.source'].isnull().sum()/test.shape[0]
# Out:
# ['google' '(direct)' 'sites.google.com' 'bing' 'mall.googleplex.com'
#  'analytics.google.com' 'gdeals.googleplex.com' 'productforums.google.com'
#  'youtube.com' 'google.com' 'blog.golang.org' 'l.facebook.com'
#  'reddit.com' 'Partners' 'google.co.jp' 'groups.google.com' 'google.co.uk'
#  'quora.com' 'sashihara.jp' 'qiita.com' 'baidu' 'docs.google.com' 'dfa'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9860' 'm.facebook.com'
#  'tpc.googlesyndication.com' 'optimize.google.com' 'lunametrics.com'
#  'yahoo' 'mail.google.com' 'google.com.au' 'm.youtube.com' 'pinterest.com'
#  'allo.google.com' 'ask' 'support.google.com' 'int.search.tb.ask.com'
#  'search.mysearch.com' 'adwords.google.com' 'blackboard.vsu.edu'
#  'web.whatsapp.com' 's0.2mdn.net' 'my.uclaextension.edu'
#  'googleads.g.doubleclick.net' 'yandex' 'linkedin.com' 'facebook.com'
#  'phandroid.com' 'grow.googleplex.com' 'google.co.th'
#  'moma.corp.google.com' 'canopy.uc.edu' 'googleux.perksplus.com'
#  'lm.facebook.com' 'away.vk.com' 'plus.url.google.com' 't.co'
#  'news.ycombinator.com' 'ca.search.yahoo.com' 'results.searchlock.com'
#  'duckduckgo.com' 'ipv6.google.com' 'it.search.yahoo.com' 'google.co.in'
#  'google.de' 'google.it' 'dealspotr.com' 'in.search.yahoo.com'
#  'googleweblight.com' 'google.dk' 'notifications.google.com'
#  'redbull.corp.google.com' 'google.hu' 'digg.com' 'google.lk'
#  'google.com.sg' 'images.google.de' 'l.messenger.com' 'search.xfinity.com'
#  'outlook.live.com' 'myactivity.google.com'
#  'sans.irv.corp.google.com:9001'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9876' 'getpocket.com'
#  'growcms.googleplex.com' 'youtube.thinkwithgoogle.com'
#  'uk.search.yahoo.com' 'google.com.br' 'google.es' 'msn.com'
#  'login.corp.google.com' 'arstechnica.com' 'tw.search.yahoo.com'
#  'nashda.mtv.corp.google.com:18080' 'google.ru'
#  'malaysia.search.yahoo.com' 'bluequill.franklin.edu' 'keep.google.com'
#  'wikihow.com' 'search.tb.ask.com' 'fr.search.yahoo.com' 'go.mail.ru'
#  'evernote.com' 'google.co.za' 'de.wow.com' 'google.com.tr'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9819' 'google.com.eg'
#  'suche.t-online.de' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9817'
#  'hangouts.google.com' 'gtm-preprod-dogfood.corp.google.com'
#  'online-metrics.com' 'plus.google.com' 'chat.google.com' 'm.baidu.com'
#  'baidu.com' 'google.com.ua' 'google.cl' 'google.ca' 'github.com'
#  'se.search.yahoo.com' 'learn.colorado.edu' 'cases.corp.google.com'
#  'web.skype.com' 'connect.googleforwork.com' 'es.search.yahoo.com'
#  'seroundtable.com' 'gophergala.com' 'analytics.corp.google.com'
#  'blognone.com' 'gtm-dogfood.corp.google.com' 'memegen.googleplex.com'
#  'web.facebook.com' 'google.by' 'us.search.yahoo.com' 'kidrex.org'
#  'info.com' 'allo.corp.google.com' 'images.google.com' 'marketingland.com'
#  'ph.search.yahoo.com' 'myaccount.google.com' 'au.search.yahoo.com'
#  'm.yz.sm.cn' 'm.sp.sm.cn' 've.search.yahoo.com' 'developers.google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9807' 'google.com.ng'
#  'vk.com' 'cse.google.com' 'sg.search.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9845' 'amp.reddit.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9842' 'apps.rackspace.com'
#  'ixquick.com' 'crowdcompute.googleplex.com' 'google.com.mx'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9878' 'br.pinterest.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9821'
#  'fletch.teams.x20web.corp.google.com' 'feedly.com' 'google.lv'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9811' 'google.co.id'
#  'ddimitrop.irv.corp.google.com:9001' 'businessinsider.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9887' 'aulagrado.esic.edu'
#  'espanol.search.yahoo.com' 'search.1and1.com'
#  'psahu2.nyc.corp.google.com:7000' 'ar.search.yahoo.com'
#  'co.search.yahoo.com' 'amazon.com' 'r.search.aol.com' 'my.yahoo.com'
#  'br.search.yahoo.com' 'google.fr' 'cn.bing.com'
#  'analytics-preprod.corp.google.com' 'google.nl' 'mx.search.yahoo.com'
#  'goto.google.com' 'chatwork.com' 'ca-mg5.mail.yahoo.com'
#  'fr-fr.facebook.com' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9872'
#  'adwords-next-devel.qa.adz.google.com' 'learn.pct.edu'
#  'myasucourses.asu.edu' 'google.lt'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9874'
#  'gearloose.corp.google.com' 'secq-ng.googleplex.com' 'm5.baidu.com'
#  'google.co.nz' 'so.com' 'hk.search.yahoo.com' 'images.google'
#  'mail1.swic.edu' 'lisham-web.blogspot.com' 'startpage.com'
#  'trends.google.com' 'mycrabnet.googleplex.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9888' 'm.sogou.com'
#  '(not set)' 'google.com.ph' 'mail.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9834' 'ru.pinterest.com'
#  'mail.aol.com' 'google.be' 'google.com.bd' 'mg.mail.yahoo.com'
#  'nl.search.yahoo.com' 'critique.corp.google.com'
#  'mahes04.nyc.corp.google.com:8778'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9873'
#  'amahesh1.hot.corp.google.com:12001'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9814'
#  'adwords-displayads.googleusercontent.com' 'it.pinterest.com'
#  'lms.uconn.edu' 'google.co.kr' 'google.co.il' 'blackboard.bentley.edu'
#  'drive.google.com' 'cases2.corp.google.com'
#  'nashda.mtv.corp.google.com:8080' 'basecamp.com' 'ipv4.google.com'
#  'google.com.hk' 'google.ch'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9899' 'de.search.yahoo.com'
#  'calendar.google.com' 'google.ge' 'flipboard.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9809' 'online.fullsail.edu'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9839'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9894'
#  'web.mail.comcast.net' 'businessinsider.sg'
#  'papyrus.mtv.corp.google.com:9011' 'google.ie' 'google.jo'
#  'cz.pinterest.com' 'centrum.cz' 'partnerads.ysm.yahoo.com'
#  'search.mywebsearch.com' 'papyrus.mtv.corp.google.com:9021'
#  'bbhosted.cuny.edu' 'home.kik.com' 'id.pinterest.com'
#  'fi.search.yahoo.com' 'google.com.ec' 'wap.sogou.com'
#  'confidential-mail.google.com' 'google.at' 'adwords.corp.google.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9895' 'id.search.yahoo.com'
#  'oscar.corp.google.com' 'kik.com' 'search.earthlink.net'
#  'moodle.aurora.edu' 'twitter.com' 'google.gr' 'ch.search.yahoo.com'
#  'thompj.mtv.corp.google.com:7000' 'aol'
#  'asanagala.hyd.corp.google.com:8621' 'icloud.com' 'nl.pinterest.com'
#  'web.telegram.org' 'search.incredibar.com'
#  'djeanz440.zrh.corp.google.com:8080' 'es.pinterest.com' 'google.ee'
#  'google.com.tw' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9875'
#  'google.pl' 'plus.sandbox.google.com' 'efbr4.prod.google.com:14159'
#  'awics.corp.google.com' 'adx.corp.google.com' 'es.yhs4.search.yahoo.com'
#  'xbidprodmirror.corp.google.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9842' 'google.com.sa'
#  'in.pinterest.com' 'search.pch.com' 'cl.search.yahoo.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9827'
#  'redwood.corp.google.com' 'biztools.corp.google.com'
#  'business.facebook.com' 'search.snapdo.com' 'smile.amazon.com'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9869' 'google.iq'
#  'google.com.pk' '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9881'
#  'g3doc.corp.google.com'
#  '0.sxs.exp.frontend.gws.stevenfortune.jm.borg.google.com:25393'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9801'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9828' 'earth.google.com'
#  'qc.search.yahoo.com' 'play.google.com'
#  '0.shared.bow.cat2.ads-bow.qk.borg.google.com:9884'
#  'uwec.courses.wisconsin.edu'
#  '0.shared.bow.cat2.ads-bow.yw.borg.google.com:9815' 'google.pt'
#  'm.wikihow.com' 'images.google.com.br' 'watchword.googleplex.com'
#  'p.qiao.baidu.com']
# 324
# 0.0

# %%
train = train.drop(useless, axis=1)
test =test.drop(useless, axis=1)

# %%
train.shape[1], test.shape[1]
# Out:
# (26, 25)

# %%
train.to_csv("../data/train_0929.csv", index=False)
test.to_csv("../data/test_0929.csv", index=False)

# %%
train=pd.read_csv('../data/train_0929.csv')
test=pd.read_csv('../data/test_0929.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### 3-3 Feature Preprocessing
# * EDA
# * missing values
# * dtypes
# * feature encoding

# %%
train.head()
# Out:
#   channelGrouping        date        fullVisitorId     visitId  visitNumber  \
# 0  Organic Search  2016-09-02  1131660440785968503  1472830385            1
# 1  Organic Search  2016-09-02   377306020877927890  1472880147            1
# 2  Organic Search  2016-09-02  3895546263509774583  1472865386            1
# 3  Organic Search  2016-09-02  4763447161404445595  1472881213            1
# 4  Organic Search  2016-09-02    27294437909732085  1472822600            2
#
#    visitStartTime device.deviceCategory  device.isMobile  \
# 0      1472830385               desktop            False
# 1      1472880147               desktop            False
# 2      1472865386               desktop            False
# 3      1472881213               desktop            False
# 4      1472822600                mobile             True
#
#   device.operatingSystem                geoNetwork.city          ...           \
# 0                Windows                          Izmir          ...
# 1              Macintosh  not available in demo dataset          ...
# 2                Windows                         Madrid          ...
# 3                  Linux  not available in demo dataset          ...
# 4                Android  not available in demo dataset          ...
#
#   totals.hits totals.newVisits totals.pageviews totals.transactionRevenue  \
# 0           1              1.0              1.0                       NaN
# 1           1              1.0              1.0                       NaN
# 2           1              1.0              1.0                       NaN
# 3           1              1.0              1.0                       NaN
# 4           1              NaN              1.0                       NaN
#
#   totals.visits  trafficSource.adwordsClickInfo.adNetworkType  \
# 0             1                                           NaN
# 1             1                                           NaN
# 2             1                                           NaN
# 3             1                                           NaN
# 4             1                                           NaN
#
#    trafficSource.campaign  trafficSource.isTrueDirect  trafficSource.keyword  \
# 0               (not set)                         NaN         (not provided)
# 1               (not set)                         NaN         (not provided)
# 2               (not set)                         NaN         (not provided)
# 3               (not set)                         NaN        google + online
# 4               (not set)                        True         (not provided)
#
#    trafficSource.medium
# 0               organic
# 1               organic
# 2               organic
# 3               organic
# 4               organic
#
# [5 rows x 26 columns]

# %%
train.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'visitId', 'visitNumber',
#        'visitStartTime', 'device.deviceCategory', 'device.isMobile',
#        'device.operatingSystem', 'geoNetwork.city', 'geoNetwork.continent',
#        'geoNetwork.country', 'geoNetwork.metro', 'geoNetwork.region',
#        'geoNetwork.subContinent', 'totals.bounces', 'totals.hits',
#        'totals.newVisits', 'totals.pageviews', 'totals.transactionRevenue',
#        'totals.visits', 'trafficSource.adwordsClickInfo.adNetworkType',
#        'trafficSource.campaign', 'trafficSource.isTrueDirect',
#        'trafficSource.keyword', 'trafficSource.medium'],
#       dtype='object')
