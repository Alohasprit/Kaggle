# %% [markdown]
# ## DT Level 3 Day-2 Bike Sharing Demand

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## 2. Loading Data

# %%
train = pd.read_csv('../../Day2/Bike Sharing Demand Data/train.csv', parse_dates=['datetime'])
test = pd.read_csv('../../Day2/Bike Sharing Demand Data/test.csv', parse_dates=['datetime'])

# %%
print(train.shape)
train.head()
# Out:
# (10886, 12)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
print(test.shape)
test.head()
# Out:
# (6493, 9)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %% [markdown]
# ## 3. Data Pre-processing

# %% [markdown]
# ### 3-1 datetime

# %%
train['year']=train['datetime'].dt.year
train['month']=train['datetime'].dt.month
train['day']=train['datetime'].dt.day
train['hour']=train['datetime'].dt.hour

test['year']=test['datetime'].dt.year
test['month']=test['datetime'].dt.month
test['day']=test['datetime'].dt.day
test['hour']=test['datetime'].dt.hour

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4

# %%
test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  hour
# 0        56    26.0027  2011      1   20     0
# 1        56     0.0000  2011      1   20     1
# 2        56     0.0000  2011      1   20     2
# 3        56    11.0014  2011      1   20     3
# 4        56    11.0014  2011      1   20     4

# %% [markdown]
# ### 3-2 Feature selection

# %%
train.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'year', 'month', 'day', 'hour'],
#       dtype='object')

# %%
train_feature_name =['season', 'holiday', 'workingday', 'weather', 'temp',
       'atemp', 'humidity', 'windspeed','year','month','day','hour','count']

test_feature_name =['season', 'holiday', 'workingday', 'weather', 'temp',
       'atemp', 'humidity', 'windspeed','year','month','day','hour',]

# %%
train = train[train_feature_name]
test = test[test_feature_name]

# %%
print(train.shape)
train.head()
# Out:
# (10886, 13)
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    year  month  day  hour  count
# 0  2011      1    1     0     16
# 1  2011      1    1     1     40
# 2  2011      1    1     2     32
# 3  2011      1    1     3     13
# 4  2011      1    1     4      1

# %%
print(test.shape)
test.head()
# Out:
# (6493, 12)
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    year  month  day  hour
# 0  2011      1   20     0
# 1  2011      1   20     1
# 2  2011      1   20     2
# 3  2011      1   20     3
# 4  2011      1   20     4

# %% [markdown]
# ### 3-3 Conver to Tensor

# %%
train = Variable(torch.FloatTensor(train.values))
test = Variable(torch.FloatTensor(test.values))

# %%
print(train.size())
train
# Out:
# torch.Size([10886, 13])
# tensor([[    1.0000,     0.0000,     0.0000,  ...,     1.0000,
#              0.0000,    16.0000],
#         [    1.0000,     0.0000,     0.0000,  ...,     1.0000,
#              1.0000,    40.0000],
#         [    1.0000,     0.0000,     0.0000,  ...,     1.0000,
#              2.0000,    32.0000],
#         ...,
#         [    4.0000,     0.0000,     1.0000,  ...,    19.0000,
#             21.0000,   168.0000],
#         [    4.0000,     0.0000,     1.0000,  ...,    19.0000,
#             22.0000,   129.0000],
#         [    4.0000,     0.0000,     1.0000,  ...,    19.0000,
#             23.0000,    88.0000]])

# %%
print(test.size())
test.data
# Out:
# torch.Size([6493, 12])
# tensor([[    1.0000,     0.0000,     1.0000,  ...,     1.0000,
#             20.0000,     0.0000],
#         [    1.0000,     0.0000,     1.0000,  ...,     1.0000,
#             20.0000,     1.0000],
#         [    1.0000,     0.0000,     1.0000,  ...,     1.0000,
#             20.0000,     2.0000],
#         ...,
#         [    1.0000,     0.0000,     1.0000,  ...,    12.0000,
#             31.0000,    21.0000],
#         [    1.0000,     0.0000,     1.0000,  ...,    12.0000,
#             31.0000,    22.0000],
#         [    1.0000,     0.0000,     1.0000,  ...,    12.0000,
#             31.0000,    23.0000]])

# %%
test.shape[0]
# Out:
# 6493

# %%
train[:,:-1]
# Out:
# tensor([[    1.0000,     0.0000,     0.0000,  ...,     1.0000,
#              1.0000,     0.0000],
#         [    1.0000,     0.0000,     0.0000,  ...,     1.0000,
#              1.0000,     1.0000],
#         [    1.0000,     0.0000,     0.0000,  ...,     1.0000,
#              1.0000,     2.0000],
#         ...,
#         [    4.0000,     0.0000,     1.0000,  ...,    12.0000,
#             19.0000,    21.0000],
#         [    4.0000,     0.0000,     1.0000,  ...,    12.0000,
#             19.0000,    22.0000],
#         [    4.0000,     0.0000,     1.0000,  ...,    12.0000,
#             19.0000,    23.0000]])

# %% [markdown]
# ### 3-4 Setting Dataloader

# %%
class dataset(Dataset):
    def __init__(self):
        self.len = train.shape[0]
        self.size = train.size()
        self.x= train[:,0:-1]
        self.y=train[:,[-1]]
        
    def __getitem__(self, index):
        return self.x[index], self.y[index]
    
    def __len__(self):
        return self.len
    

dataset = dataset()
train_loader = DataLoader(dataset=dataset, batch_size=5, shuffle=True)

# %% [markdown]
# ## 4. Model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.layers = nn.Sequential(
                                nn.Linear(12,20),
                                nn.ReLU(),
                                nn.Linear(20,10),
                                nn.ReLU(),
                                nn.Linear(10,5),
                                nn.ReLU(),
                                nn.Linear(5,5),
                                nn.ReLU(),
                                nn.Linear(5,1))
        
    def forward(self, x):
        out = self.layers(x)
        return out
        
model =Model()

# %%
model
# Out:
# Model(
#   (layers): Sequential(
#     (0): Linear(in_features=12, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=5, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=5, out_features=5, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
loss_func = nn.MSELoss(size_average=False)
optimizer = optim.SGD(model.parameters(), lr=0.001)

# %% [markdown]
# ## 5. Training

# %%
for epoch in range(50):
    for i, [x, y] in enumerate(train_loader):
        x, y = Variable(x), Variable(y)
        
        optimizer.zero_grad()
        y_pred = model(x)
        loss = loss_func(y_pred, y)
        loss.backward()
        optimizer.step()
    
        if i % 100 == 0:
            print(i, loss)
# Out:
# 0 tensor(74337.0156)
# 100 tensor(67977.1641)
# 200 tensor(65561.5000)
# 300 tensor(1.00000e+05 *
#        5.1651)
# 400 tensor(1.00000e+05 *
#        1.5522)
# 500 tensor(65905.3750)
# 600 tensor(1.00000e+05 *
#        1.3124)
# 700 tensor(1.00000e+05 *
#        1.0587)
# 800 tensor(1.00000e+05 *
#        1.1571)
# 900 tensor(78773.0469)
# 1000 tensor(70741.7031)
# 1100 tensor(1.00000e+05 *
#        3.3143)
# 1200 tensor(51508.9375)
# 1300 tensor(78765.8203)
# 1400 tensor(1.00000e+05 *
#        1.2128)
# 1500 tensor(1.00000e+05 *
#        3.0360)
# 1600 tensor(1.00000e+05 *
#        1.0425)
# 1700 tensor(1.00000e+05 *
#        1.6811)
# 1800 tensor(1.00000e+05 *
#        1.3493)
# 1900 tensor(1.00000e+05 *
#        1.4644)
# 2000 tensor(1.00000e+05 *
#        1.1047)
# 2100 tensor(1.00000e+05 *
#        1.6772)
# 0 tensor(3.3012e+05)
# 100 tensor(47040.7344)
# 200 tensor(72455.3828)
# 300 tensor(75913.8984)
# 400 tensor(23825.9824)
# 500 tensor(1.00000e+05 *
#        1.4673)
# 600 tensor(1.00000e+05 *
#        2.7488)
# 700 tensor(64088.1719)
# 800 tensor(1.00000e+05 *
#        1.6137)
# 900 tensor(58849.1016)
# 1000 tensor(1.00000e+05 *
#        1.2702)
# 1100 tensor(85866.8516)
# 1200 tensor(64344.9219)
# 1300 tensor(1.00000e+05 *
#        1.2865)
# 1400 tensor(1.00000e+05 *
#        1.9334)
# 1500 tensor(1.00000e+05 *
#        9.2470)
# 1600 tensor(1.00000e+05 *
#        5.6246)
# 1700 tensor(1.00000e+05 *
#        3.8142)
# 1800 tensor(1.00000e+05 *
#        1.1145)
# 1900 tensor(1.00000e+05 *
#        7.0512)
# 2000 tensor(66348.1719)
# 2100 tensor(1.00000e+05 *
#        1.7342)
# 0 tensor(81153.8750)
# 100 tensor(1.00000e+05 *
#        3.8508)
# 200 tensor(64047.4219)
# 300 tensor(79769.0156)
# 400 tensor(1.00000e+05 *
#        2.9530)
# 500 tensor(60594.7109)
# 600 tensor(1.00000e+05 *
#        3.9620)
# 700 tensor(27486.6113)
# 800 tensor(60488.4570)
# 900 tensor(59051.1328)
# 1000 tensor(54638.7656)
# 1100 tensor(1.00000e+05 *
#        4.2013)
# 1200 tensor(1.00000e+05 *
#        1.1835)
# 1300 tensor(1.00000e+05 *
#        1.0343)
# 1400 tensor(95796.0781)
# 1500 tensor(44568.3047)
# 1600 tensor(1.00000e+05 *
#        1.2921)
# 1700 tensor(1.00000e+05 *
#        1.0309)
# 1800 tensor(1.00000e+05 *
#        1.0717)
# 1900 tensor(76187.3125)
# 2000 tensor(1.00000e+05 *
#        1.4109)
# 2100 tensor(1.00000e+05 *
#        2.1441)
# 0 tensor(1.00000e+05 *
#        2.7418)
# 100 tensor(91462.7500)
# 200 tensor(1.00000e+05 *
#        1.1405)
# 300 tensor(1.00000e+05 *
#        3.1510)
# 400 tensor(1.00000e+05 *
#        2.0672)
# 500 tensor(1.00000e+05 *
#        2.4891)
# 600 tensor(74277.2500)
# 700 tensor(72783.3203)
# 800 tensor(1.00000e+05 *
#        1.5147)
# 900 tensor(1.00000e+05 *
#        1.1171)
# 1000 tensor(1.00000e+05 *
#        1.0690)
# 1100 tensor(1.00000e+05 *
#        2.4308)
# 1200 tensor(62355.9102)
# 1300 tensor(1.00000e+05 *
#        1.1801)
# 1400 tensor(1.00000e+05 *
#        4.5150)
# 1500 tensor(1.00000e+05 *
#        9.1165)
# 1600 tensor(54166.9297)
# 1700 tensor(1.00000e+05 *
#        1.9084)
# 1800 tensor(77996.6875)
# 1900 tensor(79035.6797)
# 2000 tensor(60036.0508)
# 2100 tensor(43605.8594)
# 0 tensor(1.00000e+05 *
#        4.0602)
# 100 tensor(84283.5469)
# 200 tensor(1.00000e+05 *
#        4.3354)
# 300 tensor(75768.0781)
# 400 tensor(88187.2734)
# 500 tensor(1.00000e+05 *
#        1.7980)
# 600 tensor(1.00000e+05 *
#        1.2504)
# 700 tensor(1.00000e+05 *
#        1.1017)
# 800 tensor(1.00000e+05 *
#        2.7047)
# 900 tensor(1.00000e+05 *
#        5.8326)
# 1000 tensor(1.00000e+05 *
#        6.5320)
# 1100 tensor(59713.0352)
# 1200 tensor(1.00000e+05 *
#        1.3775)
# 1300 tensor(1.00000e+05 *
#        1.6383)
# 1400 tensor(1.00000e+05 *
#        1.6874)
# 1500 tensor(1.00000e+05 *
#        1.7727)
# 1600 tensor(48735.7500)
# 1700 tensor(1.00000e+05 *
#        1.3829)
# 1800 tensor(1.00000e+05 *
#        6.3572)
# 1900 tensor(1.00000e+05 *
#        3.8270)
# 2000 tensor(1.00000e+05 *
#        1.1393)
# 2100 tensor(1.00000e+05 *
#        3.9722)
# 0 tensor(77093.6016)
# 100 tensor(1.00000e+05 *
#        3.5374)
# 200 tensor(1.00000e+05 *
#        4.4567)
# 300 tensor(1.00000e+05 *
#        1.7814)
# 400 tensor(1.00000e+05 *
#        1.0502)
# 500 tensor(1.0140e+06)
# 600 tensor(1.00000e+05 *
#        1.0155)
# 700 tensor(57120.8633)
# 800 tensor(1.00000e+05 *
#        2.8705)
# 900 tensor(84027.5312)
# 1000 tensor(65145.7969)
# 1100 tensor(60906.7578)
# 1200 tensor(65462.1641)
# 1300 tensor(76304.6562)
# 1400 tensor(50834.3047)
# 1500 tensor(1.00000e+05 *
#        3.6956)
# 1600 tensor(3.9797e+05)
# 1700 tensor(82881.6641)
# 1800 tensor(83706.8750)
# 1900 tensor(1.00000e+05 *
#        2.4931)
# 2000 tensor(1.00000e+05 *
#        1.0407)
# 2100 tensor(1.00000e+05 *
#        1.3760)
# 0 tensor(2.0786e+05)
# 100 tensor(1.00000e+05 *
#        1.0737)
# 200 tensor(1.00000e+05 *
#        4.8727)
# 300 tensor(1.00000e+05 *
#        3.3292)
# 400 tensor(51218.3477)
# 500 tensor(27693.9375)
# 600 tensor(63246.2305)
# 700 tensor(1.00000e+05 *
#        1.7570)
# 800 tensor(1.00000e+05 *
#        1.3419)
# 900 tensor(65698.3516)
# 1000 tensor(98336.5859)
# 1100 tensor(1.00000e+05 *
#        1.7090)
# 1200 tensor(1.00000e+05 *
#        1.2294)
# 1300 tensor(99562.3750)
# 1400 tensor(56585.8086)
# 1500 tensor(1.00000e+05 *
#        1.5775)
# 1600 tensor(61133.9102)
# 1700 tensor(74885.9766)
# 1800 tensor(1.00000e+05 *
#        2.7011)
# 1900 tensor(58411.5273)
# 2000 tensor(1.00000e+05 *
#        3.6115)
# 2100 tensor(1.00000e+05 *
#        3.1019)
# 0 tensor(83335.1719)
# 100 tensor(69274.3125)
# 200 tensor(42604.6406)
# 300 tensor(56191.1250)
# 400 tensor(1.00000e+05 *
#        1.5079)
# 500 tensor(1.00000e+05 *
#        1.4087)
# 600 tensor(52346.7422)
# 700 tensor(63627.0664)
# 800 tensor(1.00000e+05 *
#        2.2827)
# 900 tensor(73436.2031)
# 1000 tensor(60434.6797)
# 1100 tensor(73310.7266)
# 1200 tensor(61552.6523)
# 1300 tensor(39370.7812)
# 1400 tensor(1.00000e+05 *
#        2.1963)
# 1500 tensor(95768.9453)
# 1600 tensor(1.00000e+05 *
#        3.3709)
# 1700 tensor(84842.3906)
# 1800 tensor(41565.7578)
# 1900 tensor(1.00000e+05 *
#        1.4611)
# 2000 tensor(1.00000e+05 *
#        2.6008)
# 2100 tensor(1.00000e+05 *
#        1.1490)
# 0 tensor(1.00000e+05 *
#        1.6114)
# 100 tensor(92747.8281)
# 200 tensor(1.00000e+05 *
#        3.0608)
# 300 tensor(1.00000e+05 *
#        2.2727)
# 400 tensor(1.00000e+05 *
#        1.1119)
# 500 tensor(1.00000e+05 *
#        1.2191)
# 600 tensor(88659.4688)
# 700 tensor(1.00000e+05 *
#        1.3007)
# 800 tensor(1.00000e+05 *
#        1.0655)
# 900 tensor(1.00000e+05 *
#        1.1962)
# 1000 tensor(1.00000e+05 *
#        1.1353)
# 1100 tensor(1.00000e+05 *
#        1.0305)
# 1200 tensor(1.00000e+05 *
#        1.5627)
# 1300 tensor(1.00000e+05 *
#        1.1455)
# 1400 tensor(19901.7930)
# 1500 tensor(62167.9297)
# 1600 tensor(1.00000e+05 *
#        3.8028)
# 1700 tensor(50816.5469)
# 1800 tensor(60042.1875)
# 1900 tensor(72526.8203)
# 2000 tensor(3.0254e+05)
# 2100 tensor(94544.9062)
# 0 tensor(76785.5781)
# 100 tensor(1.00000e+05 *
#        1.0146)
# 200 tensor(1.00000e+05 *
#        1.0265)
# 300 tensor(1.00000e+05 *
#        3.2200)
# 400 tensor(86066.2266)
# 500 tensor(1.00000e+05 *
#        4.0881)
# 600 tensor(1.00000e+05 *
#        4.4294)
# 700 tensor(63342.9297)
# 800 tensor(42667.9570)
# 900 tensor(1.00000e+05 *
#        1.4698)
# 1000 tensor(58805.4102)
# 1100 tensor(96589.3203)
# 1200 tensor(23051.3906)
# 1300 tensor(1.00000e+05 *
#        2.0143)
# 1400 tensor(65296.9102)
# 1500 tensor(57789.1641)
# 1600 tensor(1.00000e+05 *
#        1.0382)
# 1700 tensor(1.00000e+05 *
#        1.4977)
# 1800 tensor(1.00000e+05 *
#        1.0391)
# 1900 tensor(1.00000e+05 *
#        2.3237)
# 2000 tensor(73496.7812)
# 2100 tensor(1.00000e+05 *
#        1.7408)
# 0 tensor(30471.0586)
# 100 tensor(97600.7734)
# 200 tensor(1.00000e+05 *
#        4.5107)
# 300 tensor(41784.5938)
# 400 tensor(64052.2109)
# 500 tensor(82190.5078)
# 600 tensor(1.00000e+05 *
#        1.1887)
# 700 tensor(1.00000e+05 *
#        3.5519)
# 800 tensor(68174.5469)
# 900 tensor(80948.1016)
# 1000 tensor(38316.3477)
# 1100 tensor(1.00000e+05 *
#        4.9451)
# 1200 tensor(1.00000e+05 *
#        1.6715)
# 1300 tensor(92011.2969)
# 1400 tensor(46002.4648)
# 1500 tensor(1.00000e+05 *
#        1.8328)
# 1600 tensor(54299.4883)
# 1700 tensor(1.00000e+05 *
#        2.2775)
# 1800 tensor(42534.8164)
# 1900 tensor(64829.4531)
# 2000 tensor(94870.9688)
# 2100 tensor(55326.0586)
# 0 tensor(76844.3438)
# 100 tensor(52778.3438)
# 200 tensor(80213.7266)
# 300 tensor(90547.6094)
# 400 tensor(1.00000e+05 *
#        1.2935)
# 500 tensor(1.00000e+05 *
#        1.2277)
# 600 tensor(64291.4844)
# 700 tensor(1.00000e+05 *
#        6.0926)
# 800 tensor(1.00000e+05 *
#        1.5511)
# 900 tensor(1.00000e+05 *
#        1.3935)
# 1000 tensor(1.00000e+05 *
#        4.9991)
# 1100 tensor(1.00000e+05 *
#        5.2269)
# 1200 tensor(64859.1914)
# 1300 tensor(1.00000e+05 *
#        3.0615)
# 1400 tensor(90221.2969)
# 1500 tensor(1.5650e+05)
# 1600 tensor(1.00000e+05 *
#        1.0876)
# 1700 tensor(4.7211e+05)
# 1800 tensor(68896.5781)
# 1900 tensor(30307.6016)
# 2000 tensor(89342.2656)
# 2100 tensor(1.00000e+05 *
#        3.3023)
# 0 tensor(95577.4375)
# 100 tensor(1.00000e+05 *
#        1.4615)
# 200 tensor(43233.0312)
# 300 tensor(1.00000e+05 *
#        4.4910)
# 400 tensor(1.00000e+05 *
#        1.3827)
# 500 tensor(93782.0547)
# 600 tensor(1.00000e+05 *
#        2.3251)
# 700 tensor(1.00000e+05 *
#        1.3193)
# 800 tensor(1.00000e+05 *
#        1.9645)
# 900 tensor(1.00000e+05 *
#        1.4873)
# 1000 tensor(1.00000e+05 *
#        1.1906)
# 1100 tensor(60904.1562)
# 1200 tensor(1.00000e+05 *
#        1.2504)
# 1300 tensor(43566.2031)
# 1400 tensor(1.00000e+05 *
#        1.2408)
# 1500 tensor(1.00000e+05 *
#        2.8174)
# 1600 tensor(1.00000e+05 *
#        1.2707)
# 1700 tensor(1.00000e+05 *
#        1.1535)
# 1800 tensor(1.00000e+05 *
#        1.1518)
# 1900 tensor(70250.9766)
# 2000 tensor(45995.7695)
# 2100 tensor(1.00000e+05 *
#        2.6885)
# 0 tensor(92201.5469)
# 100 tensor(1.00000e+05 *
#        1.3692)
# 200 tensor(40795.2578)
# 300 tensor(78870.7812)
# 400 tensor(1.00000e+05 *
#        1.3222)
# 500 tensor(1.00000e+05 *
#        1.1392)
# 600 tensor(1.00000e+05 *
#        7.4562)
# 700 tensor(25932.9512)
# 800 tensor(22078.8418)
# 900 tensor(1.00000e+05 *
#        2.3067)
# 1000 tensor(70647.7734)
# 1100 tensor(1.00000e+05 *
#        1.6012)
# 1200 tensor(38913.3516)
# 1300 tensor(1.00000e+05 *
#        1.0305)
# 1400 tensor(91802.)
# 1500 tensor(1.00000e+05 *
#        1.3422)
# 1600 tensor(69702.)
# 1700 tensor(1.00000e+05 *
#        5.6185)
# 1800 tensor(1.00000e+05 *
#        3.0238)
# 1900 tensor(1.00000e+05 *
#        1.0835)
# 2000 tensor(93650.2422)
# 2100 tensor(1.00000e+05 *
#        1.3197)
# 0 tensor(69261.5156)
# 100 tensor(23548.6445)
# 200 tensor(1.00000e+05 *
#        3.6222)
# 300 tensor(1.00000e+05 *
#        4.8258)
# 400 tensor(1.00000e+05 *
#        1.9378)
# 500 tensor(57974.6953)
# 600 tensor(97435.7188)
# 700 tensor(1.00000e+05 *
#        1.3518)
# 800 tensor(46643.5312)
# 900 tensor(87037.1406)
# 1000 tensor(1.00000e+05 *
#        4.0892)
# 1100 tensor(1.00000e+05 *
#        1.0208)
# 1200 tensor(1.00000e+05 *
#        1.9155)
# 1300 tensor(93063.2422)
# 1400 tensor(92492.7812)
# 1500 tensor(81021.3906)
# 1600 tensor(1.00000e+05 *
#        1.2363)
# 1700 tensor(71580.6719)
# 1800 tensor(1.00000e+05 *
#        1.0589)
# 1900 tensor(1.00000e+05 *
#        1.8172)
# 2000 tensor(96217.1484)
# 2100 tensor(83576.2031)
# 0 tensor(60467.9375)
# 100 tensor(87357.1875)
# 200 tensor(1.00000e+05 *
#        4.7899)
# 300 tensor(1.00000e+05 *
#        1.2176)
# 400 tensor(1.00000e+05 *
#        3.2119)
# 500 tensor(50664.)
# 600 tensor(85818.6875)
# 700 tensor(1.00000e+05 *
#        1.3945)
# 800 tensor(1.00000e+05 *
#        1.2675)
# 900 tensor(1.00000e+05 *
#        1.7560)
# 1000 tensor(1.00000e+05 *
#        1.2823)
# 1100 tensor(1.00000e+05 *
#        1.1244)
# 1200 tensor(1.00000e+05 *
#        1.2709)
# 1300 tensor(91143.2656)
# 1400 tensor(92548.8359)
# 1500 tensor(1.00000e+05 *
#        3.2464)
# 1600 tensor(1.00000e+05 *
#        1.4933)
# 1700 tensor(1.00000e+05 *
#        1.2694)
# 1800 tensor(1.00000e+05 *
#        1.3087)
# 1900 tensor(1.00000e+05 *
#        1.0103)
# 2000 tensor(1.00000e+05 *
#        4.0189)
# 2100 tensor(1.00000e+05 *
#        4.3296)
# 0 tensor(1.00000e+05 *
#        2.4010)
# 100 tensor(71077.8281)
# 200 tensor(75294.8906)
# 300 tensor(1.00000e+05 *
#        1.2594)
# 400 tensor(1.00000e+05 *
#        1.4772)
# 500 tensor(62445.3047)
# 600 tensor(99230.5703)
# 700 tensor(85401.9062)
# 800 tensor(1.00000e+05 *
#        3.1132)
# 900 tensor(1.00000e+05 *
#        1.7821)
# 1000 tensor(63405.8164)
# 1100 tensor(1.00000e+05 *
#        2.8498)
# 1200 tensor(1.00000e+05 *
#        1.0208)
# 1300 tensor(60046.4531)
# 1400 tensor(65254.2266)
# 1500 tensor(1.00000e+05 *
#        1.1148)
# 1600 tensor(32703.3301)
# 1700 tensor(1.00000e+05 *
#        7.8699)
# 1800 tensor(1.00000e+05 *
#        1.5440)
# 1900 tensor(41103.7188)
# 2000 tensor(80037.)
# 2100 tensor(57306.6680)
# 0 tensor(1.00000e+05 *
#        4.4258)
# 100 tensor(53169.7734)
# 200 tensor(79237.2031)
# 300 tensor(71259.1953)
# 400 tensor(1.00000e+05 *
#        6.7046)
# 500 tensor(1.00000e+05 *
#        1.1394)
# 600 tensor(1.00000e+05 *
#        1.6730)
# 700 tensor(1.00000e+05 *
#        2.8494)
# 800 tensor(1.00000e+05 *
#        2.0070)
# 900 tensor(1.00000e+05 *
#        2.8964)
# 1000 tensor(1.00000e+05 *
#        1.2804)
# 1100 tensor(1.00000e+05 *
#        5.7356)
# 1200 tensor(1.00000e+05 *
#        3.0205)
# 1300 tensor(1.00000e+05 *
#        1.0128)
# 1400 tensor(36431.5430)
# 1500 tensor(1.00000e+05 *
#        2.5187)
# 1600 tensor(1.00000e+05 *
#        1.1288)
# 1700 tensor(67202.7109)
# 1800 tensor(1.00000e+05 *
#        1.2746)
# 1900 tensor(1.00000e+05 *
#        1.3451)
# 2000 tensor(84726.4297)
# 2100 tensor(35799.0898)
# 0 tensor(38170.3906)
# 100 tensor(83947.1016)
# 200 tensor(85044.6172)
# 300 tensor(1.00000e+05 *
#        6.7759)
# 400 tensor(1.00000e+05 *
#        1.3955)
# 500 tensor(1.00000e+05 *
#        2.7959)
# 600 tensor(1.00000e+05 *
#        2.1933)
# 700 tensor(1.00000e+05 *
#        4.2595)
# 800 tensor(1.00000e+05 *
#        3.1266)
# 900 tensor(38266.2031)
# 1000 tensor(1.00000e+05 *
#        1.0860)
# 1100 tensor(74911.7734)
# 1200 tensor(1.00000e+05 *
#        4.5808)
# 1300 tensor(62019.3242)
# 1400 tensor(53711.9961)
# 1500 tensor(81936.2891)
# 1600 tensor(1.00000e+05 *
#        2.0563)
# 1700 tensor(67838.5000)
# 1800 tensor(84475.3750)
# 1900 tensor(87752.0625)
# 2000 tensor(68827.6797)
# 2100 tensor(1.00000e+05 *
#        1.5563)
# 0 tensor(1.00000e+05 *
#        2.4608)
# 100 tensor(1.00000e+05 *
#        2.0661)
# 200 tensor(78735.6250)
# 300 tensor(1.00000e+05 *
#        3.3189)
# 400 tensor(68582.1953)
# 500 tensor(1.00000e+05 *
#        1.0768)
# 600 tensor(61500.6250)
# 700 tensor(1.00000e+05 *
#        2.3739)
# 800 tensor(1.00000e+05 *
#        1.2066)
# 900 tensor(78544.8438)
# 1000 tensor(1.00000e+05 *
#        1.1842)
# 1100 tensor(1.00000e+05 *
#        2.8323)
# 1200 tensor(46600.1250)
# 1300 tensor(75958.0469)
# 1400 tensor(1.00000e+05 *
#        1.2631)
# 1500 tensor(45556.7930)
# 1600 tensor(1.00000e+05 *
#        1.7490)
# 1700 tensor(53551.5078)
# 1800 tensor(1.00000e+05 *
#        3.9064)
# 1900 tensor(99525.1719)
# 2000 tensor(1.00000e+05 *
#        2.8762)
# 2100 tensor(1.00000e+05 *
#        1.6924)
# 0 tensor(1.00000e+05 *
#        1.5347)
# 100 tensor(95584.1484)
# 200 tensor(1.00000e+05 *
#        3.2292)
# 300 tensor(1.00000e+05 *
#        1.1957)
# 400 tensor(49220.1992)
# 500 tensor(71613.1953)
# 600 tensor(1.00000e+05 *
#        4.3251)
# 700 tensor(1.00000e+05 *
#        3.1083)
# 800 tensor(1.00000e+05 *
#        2.4787)
# 900 tensor(83440.9375)
# 1000 tensor(1.00000e+05 *
#        1.2546)
# 1100 tensor(1.00000e+05 *
#        1.0374)
# 1200 tensor(71114.0625)
# 1300 tensor(1.00000e+05 *
#        1.8256)
# 1400 tensor(1.00000e+05 *
#        1.3384)
# 1500 tensor(1.00000e+05 *
#        3.3351)
# 1600 tensor(61120.6172)
# 1700 tensor(1.00000e+05 *
#        1.9345)
# 1800 tensor(1.00000e+05 *
#        8.2566)
# 1900 tensor(1.00000e+05 *
#        1.4786)
# 2000 tensor(17245.7422)
# 2100 tensor(1.00000e+05 *
#        1.4941)
# 0 tensor(1.00000e+05 *
#        3.4073)
# 100 tensor(89580.9062)
# 200 tensor(1.00000e+05 *
#        2.2098)
# 300 tensor(1.00000e+05 *
#        2.3012)
# 400 tensor(44033.9609)
# 500 tensor(54438.7539)
# 600 tensor(99487.2422)
# 700 tensor(1.00000e+05 *
#        1.6449)
# 800 tensor(81878.3281)
# 900 tensor(68838.1172)
# 1000 tensor(76198.8984)
# 1100 tensor(52102.9375)
# 1200 tensor(39625.9219)
# 1300 tensor(1.00000e+05 *
#        1.2057)
# 1400 tensor(74173.6562)
# 1500 tensor(1.00000e+05 *
#        3.9259)
# 1600 tensor(1.00000e+05 *
#        5.8038)
# 1700 tensor(1.00000e+05 *
#        1.1666)
# 1800 tensor(1.00000e+05 *
#        2.8105)
# 1900 tensor(1.00000e+05 *
#        1.3837)
# 2000 tensor(1.00000e+05 *
#        2.1476)
# 2100 tensor(1.00000e+05 *
#        1.4831)
# 0 tensor(85749.8047)
# 100 tensor(1.00000e+05 *
#        9.2907)
# 200 tensor(82768.7031)
# 300 tensor(36880.5469)
# 400 tensor(28951.6934)
# 500 tensor(1.00000e+05 *
#        1.2464)
# 600 tensor(1.00000e+05 *
#        1.1068)
# 700 tensor(1.00000e+05 *
#        1.9838)
# 800 tensor(1.00000e+05 *
#        1.1766)
# 900 tensor(1.00000e+05 *
#        3.3993)
# 1000 tensor(67631.7734)
# 1100 tensor(87442.1250)
# 1200 tensor(1.00000e+05 *
#        1.1135)
# 1300 tensor(1.00000e+05 *
#        1.3137)
# 1400 tensor(1.00000e+05 *
#        1.2362)
# 1500 tensor(3131.3643)
# 1600 tensor(51231.3398)
# 1700 tensor(1.00000e+05 *
#        3.7665)
# 1800 tensor(1.00000e+05 *
#        2.1908)
# 1900 tensor(75166.6016)
# 2000 tensor(1.00000e+05 *
#        1.2588)
# 2100 tensor(1.00000e+05 *
#        1.6524)
# 0 tensor(1.00000e+05 *
#        4.7848)
# 100 tensor(1.00000e+05 *
#        2.8516)
# 200 tensor(1.00000e+05 *
#        1.7921)
# 300 tensor(1.00000e+05 *
#        1.5545)
# 400 tensor(1.00000e+05 *
#        3.0192)
# 500 tensor(83626.1875)
# 600 tensor(1.00000e+05 *
#        2.7868)
# 700 tensor(1.00000e+05 *
#        1.2042)
# 800 tensor(81552.6797)
# 900 tensor(1.00000e+05 *
#        2.7200)
# 1000 tensor(1.00000e+05 *
#        1.4158)
# 1100 tensor(81729.9844)
# 1200 tensor(55058.5000)
# 1300 tensor(1.00000e+05 *
#        1.2119)
# 1400 tensor(1.00000e+05 *
#        1.0845)
# 1500 tensor(1.00000e+05 *
#        1.2604)
# 1600 tensor(1.00000e+05 *
#        1.4214)
# 1700 tensor(68458.1406)
# 1800 tensor(90647.4375)
# 1900 tensor(1.00000e+05 *
#        4.9680)
# 2000 tensor(19675.2676)
# 2100 tensor(65941.5078)
# 0 tensor(1.00000e+05 *
#        1.3143)
# 100 tensor(60136.9609)
# 200 tensor(1.00000e+05 *
#        3.8571)
# 300 tensor(1.00000e+05 *
#        1.9159)
# 400 tensor(1.00000e+05 *
#        5.5787)
# 500 tensor(85361.8203)
# 600 tensor(1.00000e+05 *
#        3.6999)
# 700 tensor(1.00000e+05 *
#        4.7676)
# 800 tensor(1.00000e+05 *
#        1.1893)
# 900 tensor(1.00000e+05 *
#        2.2990)
# 1000 tensor(48245.9414)
# 1100 tensor(1.00000e+05 *
#        3.9005)
# 1200 tensor(1.00000e+05 *
#        1.0371)
# 1300 tensor(32507.1895)
# 1400 tensor(82875.2188)
# 1500 tensor(1.00000e+05 *
#        1.2280)
# 1600 tensor(1.00000e+05 *
#        2.4593)
# 1700 tensor(1.5412e+05)
# 1800 tensor(59146.3906)
# 1900 tensor(1.00000e+05 *
#        1.8082)
# 2000 tensor(25347.5684)
# 2100 tensor(1.00000e+05 *
#        5.8989)
# 0 tensor(1.00000e+05 *
#        1.3356)
# 100 tensor(84232.2812)
# 200 tensor(62628.3438)
# 300 tensor(66520.2812)
# 400 tensor(83308.7109)
# 500 tensor(1.00000e+05 *
#        1.1376)
# 600 tensor(1.00000e+05 *
#        2.8559)
# 700 tensor(90931.3281)
# 800 tensor(1.00000e+05 *
#        1.5847)
# 900 tensor(1.00000e+05 *
#        1.6756)
# 1000 tensor(1.00000e+05 *
#        6.8381)
# 1100 tensor(1.00000e+05 *
#        2.5897)
# 1200 tensor(1.00000e+05 *
#        1.4937)
# 1300 tensor(1.00000e+05 *
#        2.7622)
# 1400 tensor(1.00000e+05 *
#        2.4166)
# 1500 tensor(1.00000e+05 *
#        3.4153)
# 1600 tensor(1.00000e+05 *
#        1.3859)
# 1700 tensor(98746.2578)
# 1800 tensor(1.00000e+05 *
#        1.6391)
# 1900 tensor(1.00000e+05 *
#        1.5148)
# 2000 tensor(83700.5469)
# 2100 tensor(1.00000e+05 *
#        1.0741)
# 0 tensor(1.00000e+05 *
#        1.8352)
# 100 tensor(67369.0391)
# 200 tensor(1.00000e+05 *
#        2.6792)
# 300 tensor(95083.7344)
# 400 tensor(85391.2109)
# 500 tensor(22583.1816)
# 600 tensor(1.00000e+05 *
#        1.3098)
# 700 tensor(46556.1758)
# 800 tensor(77027.3125)
# 900 tensor(78016.9766)
# 1000 tensor(1.00000e+05 *
#        1.8451)
# 1100 tensor(1.00000e+05 *
#        6.0867)
# 1200 tensor(87666.7266)
# 1300 tensor(1.00000e+05 *
#        1.6875)
# 1400 tensor(73843.6562)
# 1500 tensor(1.00000e+05 *
#        1.0696)
# 1600 tensor(51998.9023)
# 1700 tensor(1.00000e+05 *
#        1.8935)
# 1800 tensor(93494.6641)
# 1900 tensor(49543.3750)
# 2000 tensor(70667.7891)
# 2100 tensor(1.00000e+05 *
#        1.3942)
# 0 tensor(36893.0234)
# 100 tensor(76482.7969)
# 200 tensor(83713.5312)
# 300 tensor(1.00000e+05 *
#        3.2563)
# 400 tensor(36782.9102)
# 500 tensor(1.00000e+05 *
#        1.0048)
# 600 tensor(1.00000e+05 *
#        1.2303)
# 700 tensor(1.3755e+05)
# 800 tensor(1.00000e+05 *
#        1.2590)
# 900 tensor(1.00000e+05 *
#        1.0907)
# 1000 tensor(1.00000e+05 *
#        3.4682)
# 1100 tensor(47565.7266)
# 1200 tensor(1.00000e+05 *
#        1.0391)
# 1300 tensor(1.00000e+05 *
#        1.7872)
# 1400 tensor(1.00000e+05 *
#        5.5225)
# 1500 tensor(1.00000e+05 *
#        5.5996)
# 1600 tensor(1.00000e+05 *
#        2.1399)
# 1700 tensor(1.00000e+05 *
#        3.5416)
# 1800 tensor(1.00000e+05 *
#        1.0097)
# 1900 tensor(96293.7500)
# 2000 tensor(1.00000e+05 *
#        2.4355)
# 2100 tensor(1.00000e+05 *
#        3.4247)
# 0 tensor(1.00000e+05 *
#        1.0702)
# 100 tensor(66941.8906)
# 200 tensor(93814.4375)
# 300 tensor(90279.9453)
# 400 tensor(63541.8594)
# 500 tensor(1.00000e+05 *
#        7.0319)
# 600 tensor(1.00000e+05 *
#        1.3134)
# 700 tensor(86603.2188)
# 800 tensor(1.00000e+05 *
#        2.1546)
# 900 tensor(61789.3516)
# 1000 tensor(99100.5391)
# 1100 tensor(1.00000e+05 *
#        5.8087)
# 1200 tensor(85038.1953)
# 1300 tensor(50565.5273)
# 1400 tensor(66797.0625)
# 1500 tensor(49327.6562)
# 1600 tensor(1.00000e+05 *
#        1.4891)
# 1700 tensor(1.00000e+05 *
#        1.2071)
# 1800 tensor(1.00000e+05 *
#        1.3387)
# 1900 tensor(1.00000e+05 *
#        1.1574)
# 2000 tensor(1.00000e+05 *
#        2.7410)
# 2100 tensor(1.00000e+05 *
#        1.7443)
# 0 tensor(1.00000e+05 *
#        2.1141)
# 100 tensor(71256.9141)
# 200 tensor(1.00000e+05 *
#        3.0585)
# 300 tensor(1.00000e+05 *
#        1.1720)
# 400 tensor(93273.8672)
# 500 tensor(1.00000e+05 *
#        1.0390)
# 600 tensor(1.00000e+05 *
#        1.0828)
# 700 tensor(65594.4609)
# 800 tensor(46977.5625)
# 900 tensor(1.00000e+05 *
#        1.0994)
# 1000 tensor(1.00000e+05 *
#        2.2877)
# 1100 tensor(65670.6172)
# 1200 tensor(86969.6562)
# 1300 tensor(49728.0977)
# 1400 tensor(67637.4766)
# 1500 tensor(1.00000e+05 *
#        1.4811)
# 1600 tensor(80446.6016)
# 1700 tensor(56481.6602)
# 1800 tensor(86143.2578)
# 1900 tensor(1.00000e+05 *
#        2.6998)
# 2000 tensor(85339.2031)
# 2100 tensor(1.00000e+05 *
#        1.2669)
# 0 tensor(1.00000e+05 *
#        1.6248)
# 100 tensor(66015.6719)
# 200 tensor(1.00000e+05 *
#        1.4518)
# 300 tensor(76654.9219)
# 400 tensor(1.00000e+05 *
#        1.7488)
# 500 tensor(1.00000e+05 *
#        1.2597)
# 600 tensor(81176.6328)
# 700 tensor(1.00000e+05 *
#        5.2928)
# 800 tensor(1.00000e+05 *
#        3.9584)
# 900 tensor(1.00000e+05 *
#        1.2670)
# 1000 tensor(30844.6523)
# 1100 tensor(1.00000e+05 *
#        1.8393)
# 1200 tensor(82244.2969)
# 1300 tensor(59773.6875)
# 1400 tensor(36326.6914)
# 1500 tensor(1.00000e+05 *
#        4.6934)
# 1600 tensor(1.00000e+05 *
#        1.1767)
# 1700 tensor(1.00000e+05 *
#        7.2031)
# 1800 tensor(67919.4688)
# 1900 tensor(1.00000e+05 *
#        1.4348)
# 2000 tensor(90886.6094)
# 2100 tensor(1.00000e+05 *
#        3.5505)
# 0 tensor(70801.8750)
# 100 tensor(1.00000e+05 *
#        1.9055)
# 200 tensor(94499.3203)
# 300 tensor(1.00000e+05 *
#        1.0749)
# 400 tensor(77528.1406)
# 500 tensor(58644.4961)
# 600 tensor(49834.8320)
# 700 tensor(84431.3438)
# 800 tensor(59887.4922)
# 900 tensor(77823.3203)
# 1000 tensor(1.00000e+05 *
#        1.4937)
# 1100 tensor(1.00000e+05 *
#        6.3653)
# 1200 tensor(1.00000e+05 *
#        1.3655)
# 1300 tensor(87897.4453)
# 1400 tensor(58813.8125)
# 1500 tensor(1.00000e+05 *
#        2.1011)
# 1600 tensor(75630.9375)
# 1700 tensor(1.00000e+05 *
#        4.3720)
# 1800 tensor(28638.4102)
# 1900 tensor(71461.6953)
# 2000 tensor(1.00000e+05 *
#        2.0570)
# 2100 tensor(1.00000e+05 *
#        5.9268)
# 0 tensor(1.00000e+05 *
#        2.9834)
# 100 tensor(1.00000e+05 *
#        1.3337)
# 200 tensor(45276.4492)
# 300 tensor(1.00000e+05 *
#        7.3636)
# 400 tensor(34186.3242)
# 500 tensor(1.00000e+05 *
#        1.0691)
# 600 tensor(50750.9570)
# 700 tensor(1.00000e+05 *
#        4.6680)
# 800 tensor(1.00000e+05 *
#        1.8482)
# 900 tensor(1.00000e+05 *
#        2.5649)
# 1000 tensor(44023.1016)
# 1100 tensor(1.00000e+05 *
#        1.8658)
# 1200 tensor(1.00000e+05 *
#        2.1355)
# 1300 tensor(89600.7109)
# 1400 tensor(1.00000e+05 *
#        1.5688)
# 1500 tensor(1.00000e+05 *
#        1.1882)
# 1600 tensor(1.00000e+05 *
#        6.3437)
# 1700 tensor(1.00000e+05 *
#        1.1484)
# 1800 tensor(1.00000e+05 *
#        1.0391)
# 1900 tensor(42827.9805)
# 2000 tensor(1.00000e+05 *
#        1.2762)
# 2100 tensor(1.00000e+05 *
#        1.1374)
# 0 tensor(1.00000e+05 *
#        1.5695)
# 100 tensor(1.00000e+05 *
#        1.0728)
# 200 tensor(1.00000e+05 *
#        1.2411)
# 300 tensor(1.00000e+05 *
#        1.1018)
# 400 tensor(29462.0098)
# 500 tensor(1.00000e+05 *
#        1.1025)
# 600 tensor(75417.7109)
# 700 tensor(40289.4414)
# 800 tensor(1.00000e+05 *
#        2.8460)
# 900 tensor(60444.6562)
# 1000 tensor(70068.1641)
# 1100 tensor(1.00000e+05 *
#        2.6481)
# 1200 tensor(1.00000e+05 *
#        1.0740)
# 1300 tensor(43865.0469)
# 1400 tensor(90814.2188)
# 1500 tensor(91378.9375)
# 1600 tensor(1.00000e+05 *
#        1.0278)
# 1700 tensor(97288.2656)
# 1800 tensor(37114.9180)
# 1900 tensor(93960.5547)
# 2000 tensor(87777.5781)
# 2100 tensor(1.00000e+05 *
#        1.2505)
# 0 tensor(1.00000e+05 *
#        2.0218)
# 100 tensor(20336.6680)
# 200 tensor(96624.4375)
# 300 tensor(43568.2500)
# 400 tensor(83712.0938)
# 500 tensor(1.00000e+05 *
#        1.9482)
# 600 tensor(1.00000e+05 *
#        1.8474)
# 700 tensor(1.00000e+05 *
#        1.0600)
# 800 tensor(55675.6602)
# 900 tensor(1.00000e+05 *
#        1.2855)
# 1000 tensor(1.00000e+05 *
#        1.0928)
# 1100 tensor(1.00000e+05 *
#        1.0755)
# 1200 tensor(1.00000e+05 *
#        1.0435)
# 1300 tensor(1.00000e+05 *
#        1.5275)
# 1400 tensor(1.00000e+05 *
#        7.3121)
# 1500 tensor(1.00000e+05 *
#        5.6911)
# 1600 tensor(85718.2656)
# 1700 tensor(70851.3828)
# 1800 tensor(1.00000e+05 *
#        1.3026)
# 1900 tensor(99295.8438)
# 2000 tensor(1.00000e+05 *
#        1.3403)
# 2100 tensor(1.00000e+05 *
#        1.0154)
# 0 tensor(1.00000e+05 *
#        1.8120)
# 100 tensor(1.00000e+05 *
#        2.4627)
# 200 tensor(1.00000e+05 *
#        7.2722)
# 300 tensor(1.00000e+05 *
#        1.9946)
# 400 tensor(1.00000e+05 *
#        1.2870)
# 500 tensor(82067.0625)
# 600 tensor(1.00000e+05 *
#        2.7459)
# 700 tensor(1.00000e+05 *
#        2.3772)
# 800 tensor(56026.9883)
# 900 tensor(88459.5625)
# 1000 tensor(1.00000e+05 *
#        1.7130)
# 1100 tensor(88395.1328)
# 1200 tensor(1.00000e+05 *
#        1.3843)
# 1300 tensor(22925.3555)
# 1400 tensor(1.00000e+05 *
#        2.5977)
# 1500 tensor(92780.1094)
# 1600 tensor(1.00000e+05 *
#        1.1867)
# 1700 tensor(1.00000e+05 *
#        1.3432)
# 1800 tensor(1.00000e+05 *
#        1.8812)
# 1900 tensor(1.00000e+05 *
#        1.1272)
# 2000 tensor(59302.6992)
# 2100 tensor(1.00000e+05 *
#        1.0444)
# 0 tensor(1.00000e+05 *
#        1.2414)
# 100 tensor(98425.2969)
# 200 tensor(1.00000e+05 *
#        1.9654)
# 300 tensor(1.00000e+05 *
#        2.2373)
# 400 tensor(1.00000e+05 *
#        4.3684)
# 500 tensor(1.00000e+05 *
#        2.3225)
# 600 tensor(78277.8594)
# 700 tensor(1.00000e+05 *
#        2.0689)
# 800 tensor(77730.7188)
# 900 tensor(1.00000e+05 *
#        4.3769)
# 1000 tensor(44606.3516)
# 1100 tensor(1.00000e+05 *
#        6.1407)
# 1200 tensor(1.00000e+05 *
#        1.3209)
# 1300 tensor(1.00000e+05 *
#        1.7271)
# 1400 tensor(60175.2969)
# 1500 tensor(3.7382e+05)
# 1600 tensor(1.00000e+05 *
#        1.8998)
# 1700 tensor(73219.4219)
# 1800 tensor(80444.0703)
# 1900 tensor(73835.5469)
# 2000 tensor(38431.2188)
# 2100 tensor(1.00000e+05 *
#        3.6922)
# 0 tensor(83836.9219)
# 100 tensor(59665.7188)
# 200 tensor(1.00000e+05 *
#        1.2683)
# 300 tensor(1.00000e+05 *
#        5.4298)
# 400 tensor(87088.5156)
# 500 tensor(76656.8516)
# 600 tensor(72508.8828)
# 700 tensor(1.00000e+05 *
#        1.9813)
# 800 tensor(1.00000e+05 *
#        1.7753)
# 900 tensor(57121.0430)
# 1000 tensor(35032.4141)
# 1100 tensor(1.00000e+05 *
#        4.3484)
# 1200 tensor(1.00000e+05 *
#        3.1644)
# 1300 tensor(5.9437e+05)
# 1400 tensor(1.00000e+05 *
#        4.9114)
# 1500 tensor(36227.0039)
# 1600 tensor(1.00000e+05 *
#        1.4748)
# 1700 tensor(1.00000e+05 *
#        2.1270)
# 1800 tensor(1.00000e+05 *
#        2.0140)
# 1900 tensor(1.00000e+05 *
#        1.0529)
# 2000 tensor(1.00000e+05 *
#        2.3096)
# 2100 tensor(60911.3516)
# 0 tensor(1.00000e+05 *
#        1.0101)
# 100 tensor(97845.8828)
# 200 tensor(1.00000e+05 *
#        1.7170)
# 300 tensor(99554.9531)
# 400 tensor(1.00000e+05 *
#        2.1769)
# 500 tensor(1.4810e+05)
# 600 tensor(45124.0469)
# 700 tensor(52806.9297)
# 800 tensor(1.00000e+05 *
#        3.0371)
# 900 tensor(81747.4219)
# 1000 tensor(1.00000e+05 *
#        1.5360)
# 1100 tensor(79376.2188)
# 1200 tensor(1.00000e+05 *
#        2.9341)
# 1300 tensor(1.00000e+05 *
#        1.8260)
# 1400 tensor(1.00000e+05 *
#        1.3021)
# 1500 tensor(1.00000e+05 *
#        1.5856)
# 1600 tensor(74564.0391)
# 1700 tensor(51383.5117)
# 1800 tensor(1.00000e+05 *
#        1.2425)
# 1900 tensor(1.00000e+05 *
#        1.9259)
# 2000 tensor(1.00000e+05 *
#        2.1518)
# 2100 tensor(1.00000e+05 *
#        1.4108)
# 0 tensor(1.00000e+05 *
#        2.5969)
# 100 tensor(51314.0977)
# 200 tensor(84118.6641)
# 300 tensor(1.00000e+05 *
#        5.2293)
# 400 tensor(1.00000e+05 *
#        3.6105)
# 500 tensor(55176.9766)
# 600 tensor(1.00000e+05 *
#        4.0459)
# 700 tensor(60857.1758)
# 800 tensor(1.00000e+05 *
#        1.2088)
# 900 tensor(1.00000e+05 *
#        4.8782)
# 1000 tensor(53733.3594)
# 1100 tensor(40681.6758)
# 1200 tensor(1.00000e+05 *
#        3.7578)
# 1300 tensor(90485.3359)
# 1400 tensor(80342.9688)
# 1500 tensor(49656.7695)
# 1600 tensor(1.00000e+05 *
#        1.2700)
# 1700 tensor(68738.7500)
# 1800 tensor(1.00000e+05 *
#        1.2181)
# 1900 tensor(1.00000e+05 *
#        1.1950)
# 2000 tensor(1.00000e+05 *
#        1.0190)
# 2100 tensor(35223.1602)
# 0 tensor(1.00000e+05 *
#        1.2629)
# 100 tensor(69043.2109)
# 200 tensor(1.00000e+05 *
#        1.2561)
# 300 tensor(86988.7969)
# 400 tensor(1.00000e+05 *
#        1.0860)
# 500 tensor(1.00000e+05 *
#        1.0335)
# 600 tensor(1.00000e+05 *
#        1.1718)
# 700 tensor(1.00000e+05 *
#        1.5621)
# 800 tensor(1.00000e+05 *
#        1.7762)
# 900 tensor(1.00000e+05 *
#        4.0214)
# 1000 tensor(1.00000e+05 *
#        3.2454)
# 1100 tensor(1.00000e+05 *
#        1.4826)
# 1200 tensor(1.00000e+05 *
#        2.3466)
# 1300 tensor(57614.2578)
# 1400 tensor(1.00000e+05 *
#        1.9729)
# 1500 tensor(11913.4141)
# 1600 tensor(1.00000e+05 *
#        3.3129)
# 1700 tensor(1.00000e+05 *
#        3.2484)
# 1800 tensor(1.00000e+05 *
#        3.6104)
# 1900 tensor(42027.7891)
# 2000 tensor(77283.5469)
# 2100 tensor(97277.7109)
# 0 tensor(1.00000e+05 *
#        1.6385)
# 100 tensor(1.00000e+05 *
#        1.0541)
# 200 tensor(58451.4844)
# 300 tensor(33134.1367)
# 400 tensor(1.00000e+05 *
#        1.8649)
# 500 tensor(61068.3711)
# 600 tensor(1.00000e+05 *
#        1.5956)
# 700 tensor(1.00000e+05 *
#        2.6595)
# 800 tensor(1.00000e+05 *
#        5.2000)
# 900 tensor(1.00000e+05 *
#        1.7325)
# 1000 tensor(66658.0312)
# 1100 tensor(1.00000e+05 *
#        5.4790)
# 1200 tensor(81098.5234)
# 1300 tensor(1.00000e+05 *
#        2.3266)
# 1400 tensor(93845.0391)
# 1500 tensor(1.00000e+05 *
#        2.1862)
# 1600 tensor(56998.7227)
# 1700 tensor(96144.2422)
# 1800 tensor(61136.4570)
# 1900 tensor(1.00000e+05 *
#        2.6836)
# 2000 tensor(88404.3906)
# 2100 tensor(1.00000e+05 *
#        1.0955)
# 0 tensor(1.00000e+05 *
#        1.4067)
# 100 tensor(1.00000e+05 *
#        1.1786)
# 200 tensor(73474.9062)
# 300 tensor(55479.1445)
# 400 tensor(90192.4688)
# 500 tensor(88037.9062)
# 600 tensor(1.00000e+05 *
#        1.3149)
# 700 tensor(1.00000e+05 *
#        1.3554)
# 800 tensor(59138.9727)
# 900 tensor(1.00000e+05 *
#        2.8131)
# 1000 tensor(45317.1797)
# 1100 tensor(1.00000e+05 *
#        1.3412)
# 1200 tensor(1.00000e+05 *
#        2.1776)
# 1300 tensor(84167.0234)
# 1400 tensor(23953.7266)
# 1500 tensor(1.00000e+05 *
#        1.7880)
# 1600 tensor(73660.2578)
# 1700 tensor(89707.2969)
# 1800 tensor(1.00000e+05 *
#        4.0363)
# 1900 tensor(1.00000e+05 *
#        1.6454)
# 2000 tensor(1.00000e+05 *
#        1.5325)
# 2100 tensor(1.00000e+05 *
#        2.6972)
# 0 tensor(17153.5391)
# 100 tensor(62894.9062)
# 200 tensor(1.00000e+05 *
#        5.6942)
# 300 tensor(1.00000e+05 *
#        1.6473)
# 400 tensor(1.00000e+05 *
#        3.0664)
# 500 tensor(1.00000e+05 *
#        2.4165)
# 600 tensor(77419.1562)
# 700 tensor(1.00000e+05 *
#        1.3703)
# 800 tensor(46752.8672)
# 900 tensor(1.00000e+05 *
#        2.3200)
# 1000 tensor(1.00000e+05 *
#        1.8390)
# 1100 tensor(82689.5234)
# 1200 tensor(1.00000e+05 *
#        3.3206)
# 1300 tensor(92043.9062)
# 1400 tensor(1.00000e+05 *
#        1.0439)
# 1500 tensor(51314.7070)
# 1600 tensor(1.00000e+05 *
#        6.7945)
# 1700 tensor(83062.9062)
# 1800 tensor(97940.5625)
# 1900 tensor(71869.0391)
# 2000 tensor(1.00000e+05 *
#        1.5513)
# 2100 tensor(1.00000e+05 *
#        1.8834)
# 0 tensor(92583.1016)
# 100 tensor(73461.0625)
# 200 tensor(1.00000e+05 *
#        1.1981)
# 300 tensor(74943.9609)
# 400 tensor(1.00000e+05 *
#        2.1974)
# 500 tensor(1.00000e+05 *
#        1.2105)
# 600 tensor(1.00000e+05 *
#        1.1548)
# 700 tensor(1.00000e+05 *
#        1.5434)
# 800 tensor(1.00000e+05 *
#        1.4657)
# 900 tensor(1.00000e+05 *
#        5.0579)
# 1000 tensor(1.00000e+05 *
#        1.4123)
# 1100 tensor(1.00000e+05 *
#        1.1037)
# 1200 tensor(1.00000e+05 *
#        1.1476)
# 1300 tensor(1.00000e+05 *
#        2.8489)
# 1400 tensor(1.00000e+05 *
#        4.2823)
# 1500 tensor(1.00000e+05 *
#        1.0830)
# 1600 tensor(58908.6367)
# 1700 tensor(85221.2969)
# 1800 tensor(1.00000e+05 *
#        4.9228)
# 1900 tensor(1.00000e+05 *
#        1.0944)
# 2000 tensor(1.00000e+05 *
#        1.4173)
# 2100 tensor(71354.9219)
# 0 tensor(1.00000e+05 *
#        2.0081)
# 100 tensor(41203.9336)
# 200 tensor(1.00000e+05 *
#        1.8680)
# 300 tensor(1.00000e+05 *
#        1.0576)
# 400 tensor(99168.1406)
# 500 tensor(1.00000e+05 *
#        1.4699)
# 600 tensor(1.00000e+05 *
#        1.0696)
# 700 tensor(61490.2656)
# 800 tensor(1.00000e+05 *
#        3.0315)
# 900 tensor(1.00000e+05 *
#        2.0813)
# 1000 tensor(66390.2656)
# 1100 tensor(1.00000e+05 *
#        1.8026)
# 1200 tensor(93330.8281)
# 1300 tensor(89316.9219)
# 1400 tensor(1.00000e+05 *
#        1.6672)
# 1500 tensor(1.00000e+05 *
#        1.6028)
# 1600 tensor(1.00000e+05 *
#        2.6589)
# 1700 tensor(60672.0352)
# 1800 tensor(78129.7969)
# 1900 tensor(32280.8340)
# 2000 tensor(1.00000e+05 *
#        1.4008)
# 2100 tensor(1.00000e+05 *
#        1.9480)
# 0 tensor(1.00000e+05 *
#        1.7698)
# 100 tensor(1.00000e+05 *
#        1.0570)
# 200 tensor(1.00000e+05 *
#        5.7018)
# 300 tensor(1.00000e+05 *
#        1.2724)
# 400 tensor(79584.6016)
# 500 tensor(1.00000e+05 *
#        5.4801)
# 600 tensor(68467.6562)
# 700 tensor(49571.2852)
# 800 tensor(1.00000e+05 *
#        1.3754)
# 900 tensor(1.00000e+05 *
#        3.0750)
# 1000 tensor(31588.0938)
# 1100 tensor(70342.5625)
# 1200 tensor(1.00000e+05 *
#        2.1341)
# 1300 tensor(1.00000e+05 *
#        3.5916)
# 1400 tensor(1.00000e+05 *
#        3.1852)
# 1500 tensor(1.00000e+05 *
#        1.6316)
# 1600 tensor(70020.7344)
# 1700 tensor(1.00000e+05 *
#        1.2015)
# 1800 tensor(1.00000e+05 *
#        1.0277)
# 1900 tensor(1.00000e+05 *
#        5.1683)
# 2000 tensor(1.00000e+05 *
#        1.0550)
# 2100 tensor(1.00000e+05 *
#        2.6914)
# 0 tensor(40681.8398)
# 100 tensor(1.00000e+05 *
#        5.8620)
# 200 tensor(4.4499e+05)
# 300 tensor(1.00000e+05 *
#        2.0375)
# 400 tensor(94733.7656)
# 500 tensor(1.00000e+05 *
#        1.1750)
# 600 tensor(1.00000e+05 *
#        1.6065)
# 700 tensor(46323.1992)
# 800 tensor(86285.5469)
# 900 tensor(1.00000e+05 *
#        1.8532)
# 1000 tensor(19570.3457)
# 1100 tensor(1.00000e+05 *
#        2.9570)
# 1200 tensor(1.00000e+05 *
#        2.8015)
# 1300 tensor(1.2744e+05)
# 1400 tensor(1.00000e+05 *
#        2.1819)
# 1500 tensor(56912.5156)
# 1600 tensor(1.00000e+05 *
#        2.6844)
# 1700 tensor(1.00000e+05 *
#        1.5078)
# 1800 tensor(1.00000e+05 *
#        2.3173)
# 1900 tensor(80734.2891)
# 2000 tensor(1.00000e+05 *
#        1.2032)
# 2100 tensor(1.00000e+05 *
#        3.5572)
# 0 tensor(1.00000e+05 *
#        2.1087)
# 100 tensor(75279.2266)
# 200 tensor(1.00000e+05 *
#        1.7487)
# 300 tensor(1.00000e+05 *
#        1.3859)
# 400 tensor(1.00000e+05 *
#        2.0758)
# 500 tensor(1.00000e+05 *
#        2.3082)
# 600 tensor(1.00000e+05 *
#        1.5534)
# 700 tensor(61957.6953)
# 800 tensor(81231.4688)
# 900 tensor(1.00000e+05 *
#        1.3762)
# 1000 tensor(55435.6484)
# 1100 tensor(1.00000e+05 *
#        2.3083)
# 1200 tensor(1.00000e+05 *
#        6.7866)
# 1300 tensor(68208.1875)
# 1400 tensor(1.00000e+05 *
#        1.6548)
# 1500 tensor(53305.5508)
# 1600 tensor(1.00000e+05 *
#        6.1808)
# 1700 tensor(48361.2695)
# 1800 tensor(1.00000e+05 *
#        1.3344)
# 1900 tensor(83718.6250)
# 2000 tensor(1.00000e+05 *
#        2.1623)
# 2100 tensor(1.00000e+05 *
#        1.5650)
# 0 tensor(1.00000e+05 *
#        3.2558)
# 100 tensor(1.00000e+05 *
#        3.8591)
# 200 tensor(1.00000e+05 *
#        1.0566)
# 300 tensor(98631.1406)
# 400 tensor(70605.8828)
# 500 tensor(1.00000e+05 *
#        1.0873)
# 600 tensor(52852.7695)
# 700 tensor(68657.5391)
# 800 tensor(75607.5469)
# 900 tensor(52912.4883)
# 1000 tensor(1.00000e+05 *
#        1.4474)
# 1100 tensor(1.00000e+05 *
#        1.3654)
# 1200 tensor(1.00000e+05 *
#        4.7268)
# 1300 tensor(46426.4023)
# 1400 tensor(82968.2500)
# 1500 tensor(1.00000e+05 *
#        4.8076)
# 1600 tensor(1.00000e+05 *
#        2.2165)
# 1700 tensor(1.00000e+05 *
#        1.2477)
# 1800 tensor(1.00000e+05 *
#        2.7018)
# 1900 tensor(1.00000e+05 *
#        2.5975)
# 2000 tensor(1.00000e+05 *
#        2.4478)
# 2100 tensor(1.00000e+05 *
#        1.3371)

# %%
predictions=model(test)
predictions= predictions.data.numpy()
predictions=pd.DataFrame(predictions)

# %%
submit= pd.read_csv('../../Day2/Bike Sharing Demand Data/submission.csv')
submit['count'] = predictions

# %%
submit.to_csv("../../Day2/Bike Sharing Demand Data/submission.csv", index=False)
